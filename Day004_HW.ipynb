# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11468729514","type":"PushEvent","actor":{"id":52926752,"login":"watsonding","display_login":"watsonding","gravatar_id":"","url":"https://api.github.com/users/watsonding","avatar_url":"https://avatars.githubusercontent.com/u/52926752?"},"repo":{"id":229177358,"name":"watsonding/index-of-lixiaolai-class-and-personal-learning-experiences","url":"https://api.github.com/repos/watsonding/index-of-lixiaolai-class-and-personal-learning-experiences"},"payload":{"push_id":4604578059,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"5c9515196fa1ae79f314dfe0dbd7e23a10ab20cf","before":"6312b93a9d447149351564e3b08cd0b2acdb0364","commits":[{"sha":"5c9515196fa1ae79f314dfe0dbd7e23a10ab20cf","author":{"email":"52926752+watsonding@users.noreply.github.com","name":"watsonding"},"message":"Create how_to_choose_investment_target.md","distinct":true,"url":"https://api.github.com/repos/watsonding/index-of-lixiaolai-class-and-personal-learning-experiences/commits/5c9515196fa1ae79f314dfe0dbd7e23a10ab20cf"}]},"public":true,"created_at":"2020-02-08T14:56:01Z"},{"id":"11468729511","type":"PushEvent","actor":{"id":1765311,"login":"dmazur","display_login":"dmazur","gravatar_id":"","url":"https://api.github.com/users/dmazur","avatar_url":"https://avatars.githubusercontent.com/u/1765311?"},"repo":{"id":239104466,"name":"hackerspace-silesia/nospr-kopytko","url":"https://api.github.com/repos/hackerspace-silesia/nospr-kopytko"},"payload":{"push_id":4604578057,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"d1a202c9dfe7933fb66e589b2f602d74d73ef641","before":"63d62b44fc30f0ce62f5a1033f4a842a7f9dcbb8","commits":[{"sha":"d1a202c9dfe7933fb66e589b2f602d74d73ef641","author":{"email":"d.mazur@clearcode.cc","name":"Dawid Mazur"},"message":"Filtering experiments","distinct":true,"url":"https://api.github.com/repos/hackerspace-silesia/nospr-kopytko/commits/d1a202c9dfe7933fb66e589b2f602d74d73ef641"}]},"public":true,"created_at":"2020-02-08T14:56:01Z","org":{"id":4450259,"login":"hackerspace-silesia","gravatar_id":"","url":"https://api.github.com/orgs/hackerspace-silesia","avatar_url":"https://avatars.githubusercontent.com/u/4450259?"}},{"id":"11468729510","type":"PushEvent","actor":{"id":25180681,"login":"renovate-bot","display_login":"renovate-bot","gravatar_id":"","url":"https://api.github.com/users/renovate-bot","avatar_url":"https://avatars.githubusercontent.com/u/25180681?"},"repo":{"id":207331685,"name":"renovate-bot/httpbackoff","url":"https://api.github.com/repos/renovate-bot/httpbackoff"},"payload":{"push_id":4604578052,"size":0,"distinct_size":0,"ref":"refs/heads/master","head":"fe61fcecefc327099dce5ee2c68a1c7414a3e53f","before":"fe61fcecefc327099dce5ee2c68a1c7414a3e53f","commits":[]},"public":true,"created_at":"2020-02-08T14:56:01Z"},{"id":"11468729508","type":"PushEvent","actor":{"id":45572985,"login":"tridibsamanta","display_login":"tridibsamanta","gravatar_id":"","url":"https://api.github.com/users/tridibsamanta","avatar_url":"https://avatars.githubusercontent.com/u/45572985?"},"repo":{"id":239101471,"name":"tridibsamanta/Data-Structures-and-Algorithms","url":"https://api.github.com/repos/tridibsamanta/Data-Structures-and-Algorithms"},"payload":{"push_id":4604578055,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"295a689169cc0553f41e8f7871b9b4f1d8c1cd3b","before":"f3c3b458ccb62a4fe2189876b313ddedc5421f84","commits":[{"sha":"295a689169cc0553f41e8f7871b9b4f1d8c1cd3b","author":{"email":"tridibsamanta2010@gmail.com","name":"Tridib Samanta"},"message":"Kadane\'s Algorithm (Maximum Sum Sub-array)\\n\\nThe array must contain at least one positive element.","distinct":true,"url":"https://api.github.com/repos/tridibsamanta/Data-Structures-and-Algorithms/commits/295a689169cc0553f41e8f7871b9b4f1d8c1cd3b"}]},"public":true,"created_at":"2020-02-08T14:56:01Z"},{"id":"11468729507","type":"PushEvent","actor":{"id":51327049,"login":"Aluniing","display_login":"Aluniing","gravatar_id":"","url":"https://api.github.com/users/Aluniing", ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11468729514',
#   'type': 'PushEvent',
#   'actor': {'id': 52926752,
#    'login': 'watsonding',
#    'display_login': 'watsonding',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/watsonding',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52926752?'},
#   'repo': {'id': 229177358,
#    'name': 'watsonding/index-of-lixiaolai-class-and-personal-learning-experiences',
#    'url': 'https://api.github.com/repos/watsonding/index-of-lixiaolai-class-and-personal-learning-experiences'},
#   'payload': {'push_id': 4604578059,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5c9515196fa1ae79f314dfe0dbd7e23a10ab20cf',
#    'before': '6312b93a9d447149351564e3b08cd0b2acdb0364',
#    'commits': [{'sha': '5c9515196fa1ae79f314dfe0dbd7e23a10ab20cf',
#      'author': {'email': '52926752+watsonding@users.noreply.github.com',
#       'name': 'watsonding'},
#      'message': 'Create how_to_choose_investment_target.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/watsonding/index-of-lixiaolai-class-and-personal-learning-experiences/commits/5c9515196fa1ae79f314dfe0dbd7e23a10ab20cf'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729511',
#   'type': 'PushEvent',
#   'actor': {'id': 1765311,
#    'login': 'dmazur',
#    'display_login': 'dmazur',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dmazur',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1765311?'},
#   'repo': {'id': 239104466,
#    'name': 'hackerspace-silesia/nospr-kopytko',
#    'url': 'https://api.github.com/repos/hackerspace-silesia/nospr-kopytko'},
#   'payload': {'push_id': 4604578057,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd1a202c9dfe7933fb66e589b2f602d74d73ef641',
#    'before': '63d62b44fc30f0ce62f5a1033f4a842a7f9dcbb8',
#    'commits': [{'sha': 'd1a202c9dfe7933fb66e589b2f602d74d73ef641',
#      'author': {'email': 'd.mazur@clearcode.cc', 'name': 'Dawid Mazur'},
#      'message': 'Filtering experiments',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hackerspace-silesia/nospr-kopytko/commits/d1a202c9dfe7933fb66e589b2f602d74d73ef641'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z',
#   'org': {'id': 4450259,
#    'login': 'hackerspace-silesia',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hackerspace-silesia',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4450259?'}},
#  {'id': '11468729510',
#   'type': 'PushEvent',
#   'actor': {'id': 25180681,
#    'login': 'renovate-bot',
#    'display_login': 'renovate-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25180681?'},
#   'repo': {'id': 207331685,
#    'name': 'renovate-bot/httpbackoff',
#    'url': 'https://api.github.com/repos/renovate-bot/httpbackoff'},
#   'payload': {'push_id': 4604578052,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': 'fe61fcecefc327099dce5ee2c68a1c7414a3e53f',
#    'before': 'fe61fcecefc327099dce5ee2c68a1c7414a3e53f',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729508',
#   'type': 'PushEvent',
#   'actor': {'id': 45572985,
#    'login': 'tridibsamanta',
#    'display_login': 'tridibsamanta',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tridibsamanta',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45572985?'},
#   'repo': {'id': 239101471,
#    'name': 'tridibsamanta/Data-Structures-and-Algorithms',
#    'url': 'https://api.github.com/repos/tridibsamanta/Data-Structures-and-Algorithms'},
#   'payload': {'push_id': 4604578055,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '295a689169cc0553f41e8f7871b9b4f1d8c1cd3b',
#    'before': 'f3c3b458ccb62a4fe2189876b313ddedc5421f84',
#    'commits': [{'sha': '295a689169cc0553f41e8f7871b9b4f1d8c1cd3b',
#      'author': {'email': 'tridibsamanta2010@gmail.com',
#       'name': 'Tridib Samanta'},
#      'message': "Kadane's Algorithm (Maximum Sum Sub-array)\n\nThe array must contain at least one positive element.",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tridibsamanta/Data-Structures-and-Algorithms/commits/295a689169cc0553f41e8f7871b9b4f1d8c1cd3b'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729507',
#   'type': 'PushEvent',
#   'actor': {'id': 51327049,
#    'login': 'Aluniing',
#    'display_login': 'Aluniing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aluniing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51327049?'},
#   'repo': {'id': 239144760,
#    'name': 'Aluniing/nebunia-secolului',
#    'url': 'https://api.github.com/repos/Aluniing/nebunia-secolului'},
#   'payload': {'push_id': 4604578056,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3ae33e5211ad6db1b34854a389eb87bdab748bfe',
#    'before': '715c985cb374d2bb2320ac8a6ce9c6dea2f56e4f',
#    'commits': [{'sha': '3ae33e5211ad6db1b34854a389eb87bdab748bfe',
#      'author': {'email': 'delttyjfc@gmail.com', 'name': 'Aluniing'},
#      'message': 'css',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Aluniing/nebunia-secolului/commits/3ae33e5211ad6db1b34854a389eb87bdab748bfe'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729504',
#   'type': 'PushEvent',
#   'actor': {'id': 30466018,
#    'login': 'W-Qing',
#    'display_login': 'W-Qing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/W-Qing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30466018?'},
#   'repo': {'id': 135255952,
#    'name': 'W-Qing/Code',
#    'url': 'https://api.github.com/repos/W-Qing/Code'},
#   'payload': {'push_id': 4604578051,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ce2721fb802ce06da17a8e85b0672b7f54283430',
#    'before': '16a9cb41baf012c7088ebea42c7e33763dd907f6',
#    'commits': [{'sha': 'ce2721fb802ce06da17a8e85b0672b7f54283430',
#      'author': {'email': 'scorpio971028@gmail.com', 'name': 'W-Qing'},
#      'message': 'add FEStar project',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/W-Qing/Code/commits/ce2721fb802ce06da17a8e85b0672b7f54283430'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729509',
#   'type': 'ForkEvent',
#   'actor': {'id': 32267944,
#    'login': 'liubinpy',
#    'display_login': 'liubinpy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/liubinpy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32267944?'},
#   'repo': {'id': 20904437,
#    'name': 'gin-gonic/gin',
#    'url': 'https://api.github.com/repos/gin-gonic/gin'},
#   'payload': {'forkee': {'id': 239149711,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMzkxNDk3MTE=',
#     'name': 'gin',
#     'full_name': 'liubinpy/gin',
#     'private': False,
#     'owner': {'login': 'liubinpy',
#      'id': 32267944,
#      'node_id': 'MDQ6VXNlcjMyMjY3OTQ0',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/32267944?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/liubinpy',
#      'html_url': 'https://github.com/liubinpy',
#      'followers_url': 'https://api.github.com/users/liubinpy/followers',
#      'following_url': 'https://api.github.com/users/liubinpy/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/liubinpy/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/liubinpy/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/liubinpy/subscriptions',
#      'organizations_url': 'https://api.github.com/users/liubinpy/orgs',
#      'repos_url': 'https://api.github.com/users/liubinpy/repos',
#      'events_url': 'https://api.github.com/users/liubinpy/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/liubinpy/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/liubinpy/gin',
#     'description': 'Gin is a HTTP web framework written in Go (Golang). It features a Martini-like API with much better performance -- up to 40 times faster. If you need smashing performance, get yourself some Gin.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/liubinpy/gin',
#     'forks_url': 'https://api.github.com/repos/liubinpy/gin/forks',
#     'keys_url': 'https://api.github.com/repos/liubinpy/gin/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/liubinpy/gin/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/liubinpy/gin/teams',
#     'hooks_url': 'https://api.github.com/repos/liubinpy/gin/hooks',
#     'issue_events_url': 'https://api.github.com/repos/liubinpy/gin/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/liubinpy/gin/events',
#     'assignees_url': 'https://api.github.com/repos/liubinpy/gin/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/liubinpy/gin/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/liubinpy/gin/tags',
#     'blobs_url': 'https://api.github.com/repos/liubinpy/gin/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/liubinpy/gin/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/liubinpy/gin/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/liubinpy/gin/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/liubinpy/gin/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/liubinpy/gin/languages',
#     'stargazers_url': 'https://api.github.com/repos/liubinpy/gin/stargazers',
#     'contributors_url': 'https://api.github.com/repos/liubinpy/gin/contributors',
#     'subscribers_url': 'https://api.github.com/repos/liubinpy/gin/subscribers',
#     'subscription_url': 'https://api.github.com/repos/liubinpy/gin/subscription',
#     'commits_url': 'https://api.github.com/repos/liubinpy/gin/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/liubinpy/gin/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/liubinpy/gin/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/liubinpy/gin/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/liubinpy/gin/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/liubinpy/gin/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/liubinpy/gin/merges',
#     'archive_url': 'https://api.github.com/repos/liubinpy/gin/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/liubinpy/gin/downloads',
#     'issues_url': 'https://api.github.com/repos/liubinpy/gin/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/liubinpy/gin/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/liubinpy/gin/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/liubinpy/gin/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/liubinpy/gin/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/liubinpy/gin/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/liubinpy/gin/deployments',
#     'created_at': '2020-02-08T14:56:00Z',
#     'updated_at': '2020-02-08T13:45:08Z',
#     'pushed_at': '2020-02-08T12:17:10Z',
#     'git_url': 'git://github.com/liubinpy/gin.git',
#     'ssh_url': 'git@github.com:liubinpy/gin.git',
#     'clone_url': 'https://github.com/liubinpy/gin.git',
#     'svn_url': 'https://github.com/liubinpy/gin',
#     'homepage': 'https://gin-gonic.com/',
#     'size': 2231,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z',
#   'org': {'id': 7894478,
#    'login': 'gin-gonic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/gin-gonic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7894478?'}},
#  {'id': '11468729499',
#   'type': 'PushEvent',
#   'actor': {'id': 33198988,
#    'login': 'WaleedMeselhy',
#    'display_login': 'WaleedMeselhy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WaleedMeselhy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33198988?'},
#   'repo': {'id': 238868836,
#    'name': 'WaleedMeselhy/mini-system-for-truck-management',
#    'url': 'https://api.github.com/repos/WaleedMeselhy/mini-system-for-truck-management'},
#   'payload': {'push_id': 4604578048,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e5ce74539bb3d81810c8d5a8401e845499cb1f80',
#    'before': 'd0d9c092a491f7363c600cd7f913355f308b1894',
#    'commits': [{'sha': 'e5ce74539bb3d81810c8d5a8401e845499cb1f80',
#      'author': {'email': 'waleed@localhost.localdomain', 'name': 'waleed'},
#      'message': 'add readme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/WaleedMeselhy/mini-system-for-truck-management/commits/e5ce74539bb3d81810c8d5a8401e845499cb1f80'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729505',
#   'type': 'PushEvent',
#   'actor': {'id': 35954907,
#    'login': 'youlimlee',
#    'display_login': 'youlimlee',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/youlimlee',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35954907?'},
#   'repo': {'id': 239149061,
#    'name': 'youlimlee/minimal-mistakes',
#    'url': 'https://api.github.com/repos/youlimlee/minimal-mistakes'},
#   'payload': {'push_id': 4604578053,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'da1b6648e601e135fcef57a91e3b5820684cb1c6',
#    'before': '98a89164f5ae407dfe89467c2e3ac450efd76010',
#    'commits': [{'sha': 'da1b6648e601e135fcef57a91e3b5820684cb1c6',
#      'author': {'email': '35954907+youlimlee@users.noreply.github.com',
#       'name': 'youlimlee'},
#      'message': 'Delete screenshot.png',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/youlimlee/minimal-mistakes/commits/da1b6648e601e135fcef57a91e3b5820684cb1c6'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729502',
#   'type': 'PushEvent',
#   'actor': {'id': 17478096,
#    'login': 'gshanbhag525',
#    'display_login': 'gshanbhag525',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gshanbhag525',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17478096?'},
#   'repo': {'id': 238977978,
#    'name': 'gshanbhag525/AccelathonPortal',
#    'url': 'https://api.github.com/repos/gshanbhag525/AccelathonPortal'},
#   'payload': {'push_id': 4604578049,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '14ef8fcb85f678b2fb6f73da9ddacdbfe90143a7',
#    'before': '9b6ac5f1cb0d360c403d4d86d3ea8a5edc317023',
#    'commits': [{'sha': '14ef8fcb85f678b2fb6f73da9ddacdbfe90143a7',
#      'author': {'email': '17478096+gshanbhag525@users.noreply.github.com',
#       'name': 'Gunesh Shanbhag'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gshanbhag525/AccelathonPortal/commits/14ef8fcb85f678b2fb6f73da9ddacdbfe90143a7'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729506',
#   'type': 'PushEvent',
#   'actor': {'id': 199950,
#    'login': 'iamslash',
#    'display_login': 'iamslash',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iamslash',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/199950?'},
#   'repo': {'id': 52074001,
#    'name': 'iamslash/learntocode',
#    'url': 'https://api.github.com/repos/iamslash/learntocode'},
#   'payload': {'push_id': 4604578054,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3c6466c07072148780d7db915bd6fba9bb5947c2',
#    'before': 'a7d056ae4cb5c78b91ab71e883a554d8bf1cd703',
#    'commits': [{'sha': '3c6466c07072148780d7db915bd6fba9bb5947c2',
#      'author': {'email': 'iamslash@gmail.com', 'name': 'David Sun'},
#      'message': 'accepted MissingNumber',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/iamslash/learntocode/commits/3c6466c07072148780d7db915bd6fba9bb5947c2'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729498',
#   'type': 'PushEvent',
#   'actor': {'id': 47037763,
#    'login': 'amattterasu',
#    'display_login': 'amattterasu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amattterasu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47037763?'},
#   'repo': {'id': 237454971,
#    'name': 'amattterasu/network-react',
#    'url': 'https://api.github.com/repos/amattterasu/network-react'},
#   'payload': {'push_id': 4604578045,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '13f6ee0b312fc3e7af366a100f5285f78eb58ce6',
#    'before': 'd1edc66f397a41d851906ef6b1bba11a08f5885c',
#    'commits': [{'sha': '13f6ee0b312fc3e7af366a100f5285f78eb58ce6',
#      'author': {'email': 'amattterasuuu@gmail.com',
#       'name': 'Andrey Gubaydullin'},
#      'message': 'added button disabled follow/unfollow',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/amattterasu/network-react/commits/13f6ee0b312fc3e7af366a100f5285f78eb58ce6'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729497',
#   'type': 'PushEvent',
#   'actor': {'id': 50125301,
#    'login': 'sgrant0225',
#    'display_login': 'sgrant0225',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sgrant0225',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50125301?'},
#   'repo': {'id': 238583629,
#    'name': 'sgrant0225/cli-applications-simple-blackjack-online-web-prework',
#    'url': 'https://api.github.com/repos/sgrant0225/cli-applications-simple-blackjack-online-web-prework'},
#   'payload': {'push_id': 4604578047,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': 'fdd680b09c526938960abd68bbf679e4666aa1a7',
#    'before': '40ec22888bb796d03aa0517f24ba93ac9955574d',
#    'commits': [{'sha': 'fdd680b09c526938960abd68bbf679e4666aa1a7',
#      'author': {'email': 'sharnellgrant@gmail.com', 'name': 'Sharnell Grant'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sgrant0225/cli-applications-simple-blackjack-online-web-prework/commits/fdd680b09c526938960abd68bbf679e4666aa1a7'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729495',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 135550048,
#    'name': 'bakjs/hapi-sequelize',
#    'url': 'https://api.github.com/repos/bakjs/hapi-sequelize'},
#   'payload': {'action': 'opened',
#    'number': 30,
#    'pull_request': {'url': 'https://api.github.com/repos/bakjs/hapi-sequelize/pulls/30',
#     'id': 372722712,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzcyNzIyNzEy',
#     'html_url': 'https://github.com/bakjs/hapi-sequelize/pull/30',
#     'diff_url': 'https://github.com/bakjs/hapi-sequelize/pull/30.diff',
#     'patch_url': 'https://github.com/bakjs/hapi-sequelize/pull/30.patch',
#     'issue_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/issues/30',
#     'number': 30,
#     'state': 'open',
#     'locked': False,
#     'title': 'chore(deps): update devdependency lint-staged to v10',
#     'user': {'login': 'renovate[bot]',
#      'id': 29139614,
#      'node_id': 'MDM6Qm90MjkxMzk2MTQ=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/in/2740?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/renovate%5Bbot%5D',
#      'html_url': 'https://github.com/apps/renovate',
#      'followers_url': 'https://api.github.com/users/renovate%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/renovate%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/renovate%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/renovate%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/renovate%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/renovate%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/renovate%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/renovate%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/renovate%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'This PR contains the following updates:\n\n| Package | Type | Update | Change |\n|---|---|---|---|\n| [lint-staged](https://togithub.com/okonet/lint-staged) | devDependencies | major | [`7.3.0` -> `10.0.7`](https://renovatebot.com/diffs/npm/lint-staged/7.3.0/10.0.7) |\n\n---\n\n### Release Notes\n\n<details>\n<summary>okonet/lint-staged</summary>\n\n### [`v10.0.7`](https://togithub.com/okonet/lint-staged/releases/v10.0.7)\n\n[Compare Source](https://togithub.com/okonet/lint-staged/compare/v10.0.6...v10.0.7)\n\n##### Bug Fixes\n\n-   replace fs.promises with util.promisify ([#&#8203;786](https://togithub.com/okonet/lint-staged/issues/786)) ([f71c1c9](https://togithub.com/okonet/lint-staged/commit/f71c1c9ad2d27205199171bf3dc0e908889ba384))\n\n### [`v10.0.6`](https://togithub.com/okonet/lint-staged/releases/v10.0.6)\n\n[Compare Source](https://togithub.com/okonet/lint-staged/compare/v10.0.5...v10.0.6)\n\n##### Bug Fixes\n\n-   make sure deleted files aren\'t restored due to git bugs ([#&#8203;778](https://togithub.com/okonet/lint-staged/issues/778)) ([6bfbe6c](https://togithub.com/okonet/lint-staged/commit/6bfbe6c204e351bd7055c5ecc810e1f9074304da))\n\n### [`v10.0.5`](https://togithub.com/okonet/lint-staged/releases/v10.0.5)\n\n[Compare Source](https://togithub.com/okonet/lint-staged/compare/v10.0.4...v10.0.5)\n\n##### Bug Fixes\n\n-   always resolve real git config dir location if .git is a file ([#&#8203;784](https://togithub.com/okonet/lint-staged/issues/784)) ([b98a5ed](https://togithub.com/okonet/lint-staged/commit/b98a5ed8d422f637af4157a157676a70e3f1981a))\n\n### [`v10.0.4`](https://togithub.com/okonet/lint-staged/releases/v10.0.4)\n\n[Compare Source](https://togithub.com/okonet/lint-staged/compare/v10.0.3...v10.0.4)\n\n##### Bug Fixes\n\n-   use verbose renderer when TERM=dumb ([#&#8203;782](https://togithub.com/okonet/lint-staged/issues/782)) ([9c08e8e](https://togithub.com/okonet/lint-staged/commit/9c08e8ee0bdf00de7dc6e15cd660e6fc55129832))\n\n### [`v10.0.3`](https://togithub.com/okonet/lint-staged/releases/v10.0.3)\n\n[Compare Source](https://togithub.com/okonet/lint-staged/compare/v10.0.2...v10.0.3)\n\n##### Bug Fixes\n\n-   correctly restore untracked files after running ([#&#8203;780](https://togithub.com/okonet/lint-staged/issues/780)) ([4010db0](https://togithub.com/okonet/lint-staged/commit/4010db09f6d168af677bd4ca1c815ba40460ae80))\n\n### [`v10.0.2`](https://togithub.com/okonet/lint-staged/releases/v10.0.2)\n\n[Compare Source](https://togithub.com/okonet/lint-staged/compare/v10.0.1...v10.0.2)\n\n##### Bug Fixes\n\n-   only warn about git add when it\'s the exact command ([24febb3](https://togithub.com/okonet/lint-staged/commit/24febb3c906dd84f8ee19bae74509e42db034380))\n-   parse command string with string-argv unless --shell is used ([4cb4dde](https://togithub.com/okonet/lint-staged/commit/4cb4ddee0c6b6500eefd20eb3d1bad249d51b96a))\n-   print a better warning when the initial commit is missing ([293547d](https://togithub.com/okonet/lint-staged/commit/293547d46080eac007393709a0d63a63f2063fff))\n\n### [`v10.0.1`](https://togithub.com/okonet/lint-staged/releases/v10.0.1)\n\n[Compare Source](https://togithub.com/okonet/lint-staged/compare/v10.0.0...v10.0.1)\n\n##### Bug Fixes\n\n-   preserve merge states in submodules ([#&#8203;769](https://togithub.com/okonet/lint-staged/issues/769)) ([e646b2c](https://togithub.com/okonet/lint-staged/commit/e646b2c46ad34344b526462200471fa47dcc398f))\n\n### [`v10.0.0`](https://togithub.com/okonet/lint-staged/releases/v10.0.0)\n\n[Compare Source](https://togithub.com/okonet/lint-staged/compare/v9.5.0...v10.0.0)\n\n##### Bug Fixes\n\n-   add all modified files to git index with `git add .` ([bf532c2](https://togithub.com/okonet/lint-staged/commit/bf532c2af9dbd3514b16768a106fea82ddc99923))\n-   automatically add modifications only to originally staged files ([083b8e7](https://togithub.com/okonet/lint-staged/commit/083b8e7d67307a177d427d694ead22cb0c95b0ca))\n-   better worka ...
#     'created_at': '2020-02-08T14:56:00Z',
#     'updated_at': '2020-02-08T14:56:00Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/pulls/30/commits',
#     'review_comments_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/pulls/30/comments',
#     'review_comment_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/issues/30/comments',
#     'statuses_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/statuses/8d17437a114b4b90c5a988fdaafd9e4f61c95a31',
#     'head': {'label': 'bakjs:renovate/lint-staged-10.x',
#      'ref': 'renovate/lint-staged-10.x',
#      'sha': '8d17437a114b4b90c5a988fdaafd9e4f61c95a31',
#      'user': {'login': 'bakjs',
#       'id': 30502381,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMwNTAyMzgx',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/30502381?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/bakjs',
#       'html_url': 'https://github.com/bakjs',
#       'followers_url': 'https://api.github.com/users/bakjs/followers',
#       'following_url': 'https://api.github.com/users/bakjs/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/bakjs/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/bakjs/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/bakjs/subscriptions',
#       'organizations_url': 'https://api.github.com/users/bakjs/orgs',
#       'repos_url': 'https://api.github.com/users/bakjs/repos',
#       'events_url': 'https://api.github.com/users/bakjs/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/bakjs/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 135550048,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzU1NTAwNDg=',
#       'name': 'hapi-sequelize',
#       'full_name': 'bakjs/hapi-sequelize',
#       'private': False,
#       'owner': {'login': 'bakjs',
#        'id': 30502381,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMwNTAyMzgx',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/30502381?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/bakjs',
#        'html_url': 'https://github.com/bakjs',
#        'followers_url': 'https://api.github.com/users/bakjs/followers',
#        'following_url': 'https://api.github.com/users/bakjs/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/bakjs/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/bakjs/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/bakjs/subscriptions',
#        'organizations_url': 'https://api.github.com/users/bakjs/orgs',
#        'repos_url': 'https://api.github.com/users/bakjs/repos',
#        'events_url': 'https://api.github.com/users/bakjs/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/bakjs/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/bakjs/hapi-sequelize',
#       'description': 'Hapi.js plugin for the Sequelize ORM',
#       'fork': False,
#       'url': 'https://api.github.com/repos/bakjs/hapi-sequelize',
#       'forks_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/forks',
#       'keys_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/teams',
#       'hooks_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/hooks',
#       'issue_events_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/events',
#       'assignees_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/tags',
#       'blobs_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/languages',
#       'stargazers_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/stargazers',
#       'contributors_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/contributors',
#       'subscribers_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/subscribers',
#       'subscription_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/subscription',
#       'commits_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/merges',
#       'archive_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/downloads',
#       'issues_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/deployments',
#       'created_at': '2018-05-31T07:43:34Z',
#       'updated_at': '2019-07-15T18:40:18Z',
#       'pushed_at': '2020-02-08T14:55:59Z',
#       'git_url': 'git://github.com/bakjs/hapi-sequelize.git',
#       'ssh_url': 'git@github.com:bakjs/hapi-sequelize.git',
#       'clone_url': 'https://github.com/bakjs/hapi-sequelize.git',
#       'svn_url': 'https://github.com/bakjs/hapi-sequelize',
#       'homepage': '',
#       'size': 122,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 1,
#       'open_issues': 14,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     'base': {'label': 'bakjs:master',
#      'ref': 'master',
#      'sha': '4d69d53b95c236df42b4446845e143f79d4ade10',
#      'user': {'login': 'bakjs',
#       'id': 30502381,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMwNTAyMzgx',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/30502381?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/bakjs',
#       'html_url': 'https://github.com/bakjs',
#       'followers_url': 'https://api.github.com/users/bakjs/followers',
#       'following_url': 'https://api.github.com/users/bakjs/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/bakjs/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/bakjs/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/bakjs/subscriptions',
#       'organizations_url': 'https://api.github.com/users/bakjs/orgs',
#       'repos_url': 'https://api.github.com/users/bakjs/repos',
#       'events_url': 'https://api.github.com/users/bakjs/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/bakjs/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 135550048,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzU1NTAwNDg=',
#       'name': 'hapi-sequelize',
#       'full_name': 'bakjs/hapi-sequelize',
#       'private': False,
#       'owner': {'login': 'bakjs',
#        'id': 30502381,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMwNTAyMzgx',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/30502381?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/bakjs',
#        'html_url': 'https://github.com/bakjs',
#        'followers_url': 'https://api.github.com/users/bakjs/followers',
#        'following_url': 'https://api.github.com/users/bakjs/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/bakjs/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/bakjs/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/bakjs/subscriptions',
#        'organizations_url': 'https://api.github.com/users/bakjs/orgs',
#        'repos_url': 'https://api.github.com/users/bakjs/repos',
#        'events_url': 'https://api.github.com/users/bakjs/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/bakjs/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/bakjs/hapi-sequelize',
#       'description': 'Hapi.js plugin for the Sequelize ORM',
#       'fork': False,
#       'url': 'https://api.github.com/repos/bakjs/hapi-sequelize',
#       'forks_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/forks',
#       'keys_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/teams',
#       'hooks_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/hooks',
#       'issue_events_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/events',
#       'assignees_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/tags',
#       'blobs_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/languages',
#       'stargazers_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/stargazers',
#       'contributors_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/contributors',
#       'subscribers_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/subscribers',
#       'subscription_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/subscription',
#       'commits_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/merges',
#       'archive_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/downloads',
#       'issues_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/bakjs/hapi-sequelize/deployments',
#       'created_at': '2018-05-31T07:43:34Z',
#       'updated_at': '2019-07-15T18:40:18Z',
#       'pushed_at': '2020-02-08T14:55:59Z',
#       'git_url': 'git://github.com/bakjs/hapi-sequelize.git',
#       'ssh_url': 'git@github.com:bakjs/hapi-sequelize.git',
#       'clone_url': 'https://github.com/bakjs/hapi-sequelize.git',
#       'svn_url': 'https://github.com/bakjs/hapi-sequelize',
#       'homepage': '',
#       'size': 122,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 1,
#       'open_issues': 14,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/bakjs/hapi-sequelize/pulls/30'},
#      'html': {'href': 'https://github.com/bakjs/hapi-sequelize/pull/30'},
#      'issue': {'href': 'https://api.github.com/repos/bakjs/hapi-sequelize/issues/30'},
#      'comments': {'href': 'https://api.github.com/repos/bakjs/hapi-sequelize/issues/30/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/bakjs/hapi-sequelize/pulls/30/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/bakjs/hapi-sequelize/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/bakjs/hapi-sequelize/pulls/30/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/bakjs/hapi-sequelize/statuses/8d17437a114b4b90c5a988fdaafd9e4f61c95a31'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 344,
#     'deletions': 698,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z',
#   'org': {'id': 30502381,
#    'login': 'bakjs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/bakjs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30502381?'}},
#  {'id': '11468729491',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 36754821,
#    'login': 'codeclimate[bot]',
#    'display_login': 'codeclimate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codeclimate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36754821?'},
#   'repo': {'id': 233594950,
#    'name': 'ttimt/Short_Cutteer',
#    'url': 'https://api.github.com/repos/ttimt/Short_Cutteer'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ttimt/Short_Cutteer/issues/3',
#     'repository_url': 'https://api.github.com/repos/ttimt/Short_Cutteer',
#     'labels_url': 'https://api.github.com/repos/ttimt/Short_Cutteer/issues/3/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ttimt/Short_Cutteer/issues/3/comments',
#     'events_url': 'https://api.github.com/repos/ttimt/Short_Cutteer/issues/3/events',
#     'html_url': 'https://github.com/ttimt/Short_Cutteer/pull/3',
#     'id': 551805650,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzY0NDUxNzA1',
#     'number': 3,
#     'title': 'Develop',
#     'user': {'login': 'ttimt',
#      'id': 16218167,
#      'node_id': 'MDQ6VXNlcjE2MjE4MTY3',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/16218167?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ttimt',
#      'html_url': 'https://github.com/ttimt',
#      'followers_url': 'https://api.github.com/users/ttimt/followers',
#      'following_url': 'https://api.github.com/users/ttimt/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ttimt/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ttimt/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ttimt/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ttimt/orgs',
#      'repos_url': 'https://api.github.com/users/ttimt/repos',
#      'events_url': 'https://api.github.com/users/ttimt/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ttimt/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2020-01-18T18:28:20Z',
#     'updated_at': '2020-02-08T14:56:00Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'pull_request': {'url': 'https://api.github.com/repos/ttimt/Short_Cutteer/pulls/3',
#      'html_url': 'https://github.com/ttimt/Short_Cutteer/pull/3',
#      'diff_url': 'https://github.com/ttimt/Short_Cutteer/pull/3.diff',
#      'patch_url': 'https://github.com/ttimt/Short_Cutteer/pull/3.patch'},
#     'body': ''},
#    'comment': {'url': 'https://api.github.com/repos/ttimt/Short_Cutteer/issues/comments/583743581',
#     'html_url': 'https://github.com/ttimt/Short_Cutteer/pull/3#issuecomment-583743581',
#     'issue_url': 'https://api.github.com/repos/ttimt/Short_Cutteer/issues/3',
#     'id': 583743581,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU4Mzc0MzU4MQ==',
#     'user': {'login': 'codeclimate[bot]',
#      'id': 36754821,
#      'node_id': 'MDM6Qm90MzY3NTQ4MjE=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/9403?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/codeclimate%5Bbot%5D',
#      'html_url': 'https://github.com/apps/codeclimate',
#      'followers_url': 'https://api.github.com/users/codeclimate%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/codeclimate%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/codeclimate%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/codeclimate%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/codeclimate%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/codeclimate%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/codeclimate%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/codeclimate%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/codeclimate%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-02-08T14:56:00Z',
#     'updated_at': '2020-02-08T14:56:00Z',
#     'author_association': 'NONE',
#     'body': 'Code Climate has analyzed commit 0284cc14 and detected **0 issues** on this pull request.\n\nView more on [Code Climate](https://codeclimate.com/github/ttimt/Short_Cutteer/pull/3).\n'}},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729488',
#   'type': 'PushEvent',
#   'actor': {'id': 60098615,
#    'login': 'Developer-JG',
#    'display_login': 'Developer-JG',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Developer-JG',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60098615?'},
#   'repo': {'id': 235100117,
#    'name': 'Developer-JG/RPG_studio',
#    'url': 'https://api.github.com/repos/Developer-JG/RPG_studio'},
#   'payload': {'push_id': 4604578040,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7180a03d69b3e63d36d903b03ddbf132383e82df',
#    'before': 'b1415c5b898bb55297bf4b8e016f12dfae96f945',
#    'commits': [{'sha': '7180a03d69b3e63d36d903b03ddbf132383e82df',
#      'author': {'email': 'h5638880@naver.com', 'name': 'Developer-JG'},
#      'message': '-',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Developer-JG/RPG_studio/commits/7180a03d69b3e63d36d903b03ddbf132383e82df'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729487',
#   'type': 'PushEvent',
#   'actor': {'id': 17426443,
#    'login': 'kunfayakun',
#    'display_login': 'kunfayakun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kunfayakun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17426443?'},
#   'repo': {'id': 239140839,
#    'name': 'kunfayakun/kunfayakun',
#    'url': 'https://api.github.com/repos/kunfayakun/kunfayakun'},
#   'payload': {'push_id': 4604578031,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b4f4819dec91d79d88b9d9d2c0af399deb007b37',
#    'before': 'b3fae30200c6c856b1bb6ade3bbf81316e2aeb4a',
#    'commits': [{'sha': 'b4f4819dec91d79d88b9d9d2c0af399deb007b37',
#      'author': {'email': 'kunfayakun@mailinator.com', 'name': 'kunfayakun'},
#      'message': 'GIT CloneShare Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kunfayakun/kunfayakun/commits/b4f4819dec91d79d88b9d9d2c0af399deb007b37'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:01Z'},
#  {'id': '11468729485',
#   'type': 'PushEvent',
#   'actor': {'id': 42746240,
#    'login': 'bukajj',
#    'display_login': 'bukajj',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bukajj',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42746240?'},
#   'repo': {'id': 239146665,
#    'name': 'bukajj/Budget',
#    'url': 'https://api.github.com/repos/bukajj/Budget'},
#   'payload': {'push_id': 4604578039,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2461025f98c5592381726dd2ca041523e6e823eb',
# ...
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'martin2250:master',
#      'ref': 'master',
#      'sha': '48387c5071e4b023494f7d79c041a8b4f10ba30e',
#      'user': {'login': 'martin2250',
#       'id': 8293473,
#       'node_id': 'MDQ6VXNlcjgyOTM0NzM=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/8293473?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/martin2250',
#       'html_url': 'https://github.com/martin2250',
#       'followers_url': 'https://api.github.com/users/martin2250/followers',
#       'following_url': 'https://api.github.com/users/martin2250/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/martin2250/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/martin2250/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/martin2250/subscriptions',
#       'organizations_url': 'https://api.github.com/users/martin2250/orgs',
#       'repos_url': 'https://api.github.com/users/martin2250/repos',
#       'events_url': 'https://api.github.com/users/martin2250/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/martin2250/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 209943029,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDk5NDMwMjk=',
#       'name': 'dotfiles',
#       'full_name': 'martin2250/dotfiles',
#       'private': False,
#       'owner': {'login': 'martin2250',
#        'id': 8293473,
#        'node_id': 'MDQ6VXNlcjgyOTM0NzM=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/8293473?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/martin2250',
#        'html_url': 'https://github.com/martin2250',
#        'followers_url': 'https://api.github.com/users/martin2250/followers',
#        'following_url': 'https://api.github.com/users/martin2250/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/martin2250/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/martin2250/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/martin2250/subscriptions',
#        'organizations_url': 'https://api.github.com/users/martin2250/orgs',
#        'repos_url': 'https://api.github.com/users/martin2250/repos',
#        'events_url': 'https://api.github.com/users/martin2250/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/martin2250/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/martin2250/dotfiles',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/martin2250/dotfiles',
#       'forks_url': 'https://api.github.com/repos/martin2250/dotfiles/forks',
#       'keys_url': 'https://api.github.com/repos/martin2250/dotfiles/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/martin2250/dotfiles/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/martin2250/dotfiles/teams',
#       'hooks_url': 'https://api.github.com/repos/martin2250/dotfiles/hooks',
#       'issue_events_url': 'https://api.github.com/repos/martin2250/dotfiles/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/martin2250/dotfiles/events',
#       'assignees_url': 'https://api.github.com/repos/martin2250/dotfiles/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/martin2250/dotfiles/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/martin2250/dotfiles/tags',
#       'blobs_url': 'https://api.github.com/repos/martin2250/dotfiles/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/martin2250/dotfiles/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/martin2250/dotfiles/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/martin2250/dotfiles/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/martin2250/dotfiles/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/martin2250/dotfiles/languages',
#       'stargazers_url': 'https://api.github.com/repos/martin2250/dotfiles/stargazers',
#       'contributors_url': 'https://api.github.com/repos/martin2250/dotfiles/contributors',
#       'subscribers_url': 'https://api.github.com/repos/martin2250/dotfiles/subscribers',
#       'subscription_url': 'https://api.github.com/repos/martin2250/dotfiles/subscription',
#       'commits_url': 'https://api.github.com/repos/martin2250/dotfiles/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/martin2250/dotfiles/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/martin2250/dotfiles/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/martin2250/dotfiles/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/martin2250/dotfiles/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/martin2250/dotfiles/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/martin2250/dotfiles/merges',
#       'archive_url': 'https://api.github.com/repos/martin2250/dotfiles/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/martin2250/dotfiles/downloads',
#       'issues_url': 'https://api.github.com/repos/martin2250/dotfiles/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/martin2250/dotfiles/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/martin2250/dotfiles/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/martin2250/dotfiles/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/martin2250/dotfiles/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/martin2250/dotfiles/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/martin2250/dotfiles/deployments',
#       'created_at': '2019-09-21T07:24:07Z',
#       'updated_at': '2020-02-08T13:58:09Z',
#       'pushed_at': '2020-02-08T14:54:42Z',
#       'git_url': 'git://github.com/martin2250/dotfiles.git',
#       'ssh_url': 'git@github.com:martin2250/dotfiles.git',
#       'clone_url': 'https://github.com/martin2250/dotfiles.git',
#       'svn_url': 'https://github.com/martin2250/dotfiles',
#       'homepage': None,
#       'size': 61,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Shell',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 2,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/martin2250/dotfiles/pulls/1'},
#      'html': {'href': 'https://github.com/martin2250/dotfiles/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/martin2250/dotfiles/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/martin2250/dotfiles/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/martin2250/dotfiles/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/martin2250/dotfiles/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/martin2250/dotfiles/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/martin2250/dotfiles/statuses/a6d4e85ef76f63a9bf6c1b07558add93fc05d471'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': False,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 6,
#     'additions': 25,
#     'deletions': 4,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2020-02-08T14:56:00Z'},
#  {'id': '11468729471',
#   'type': 'CreateEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 45517962,
#    'name': 'wadackel/sweet-scroll',
#    'url': 'https://api.github.com/repos/wadackel/sweet-scroll'},
#   'payload': {'ref': 'renovate/major-jest-monorepo',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': ':lollipop: ECMAScript2015+ & TypeScript Friendly, dependency-free smooth scroll library.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-08T14:56:00Z'},
#  {'id': '11468729470',
#   'type': 'ForkEvent',
#   'actor': {'id': 17148,
#    'login': 'Link2k5',
#    'display_login': 'Link2k5',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Link2k5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17148?'},
#   'repo': {'id': 40089806,
#    'name': 'wesbos/What-The-Flexbox',
#    'url': 'https://api.github.com/repos/wesbos/What-The-Flexbox'},
#   'payload': {'forkee': {'id': 239149708,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMzkxNDk3MDg=',
#     'name': 'What-The-Flexbox',
#     'full_name': 'Link2k5/What-The-Flexbox',
#     'private': False,
#     'owner': {'login': 'Link2k5',
#      'id': 17148,
#      'node_id': 'MDQ6VXNlcjE3MTQ4',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/17148?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Link2k5',
#      'html_url': 'https://github.com/Link2k5',
#      'followers_url': 'https://api.github.com/users/Link2k5/followers',
#      'following_url': 'https://api.github.com/users/Link2k5/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Link2k5/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Link2k5/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Link2k5/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Link2k5/orgs',
#      'repos_url': 'https://api.github.com/users/Link2k5/repos',
#      'events_url': 'https://api.github.com/users/Link2k5/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Link2k5/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/Link2k5/What-The-Flexbox',
#     'description': 'Exercises for the What The Flexbox video series - available at Flexbox.io',
#     'fork': True,
#     'url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox',
#     'forks_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/forks',
#     'keys_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/teams',
#     'hooks_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/hooks',
#     'issue_events_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/events',
#     'assignees_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/tags',
#     'blobs_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/languages',
#     'stargazers_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/stargazers',
#     'contributors_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/contributors',
#     'subscribers_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/subscribers',
#     'subscription_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/subscription',
#     'commits_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/merges',
#     'archive_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/downloads',
#     'issues_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/Link2k5/What-The-Flexbox/deployments',
#     'created_at': '2020-02-08T14:56:00Z',
#     'updated_at': '2020-02-07T08:44:33Z',
#     'pushed_at': '2020-02-03T22:36:34Z',
#     'git_url': 'git://github.com/Link2k5/What-The-Flexbox.git',
#     'ssh_url': 'git@github.com:Link2k5/What-The-Flexbox.git',
#     'clone_url': 'https://github.com/Link2k5/What-The-Flexbox.git',
#     'svn_url': 'https://github.com/Link2k5/What-The-Flexbox',
#     'homepage': None,
#     'size': 5912,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-02-08T14:56:00Z'},
#  {'id': '11468729466',
#   'type': 'PushEvent',
#   'actor': {'id': 17698387,
#    'login': 'Jprimero15',
#    'display_login': 'Jprimero15',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jprimero15',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17698387?'},
#   'repo': {'id': 143698601,
#    'name': 'Jprimero15/android_device_samsung_hlte',
#    'url': 'https://api.github.com/repos/Jprimero15/android_device_samsung_hlte'},
#   'payload': {'push_id': 4604578027,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/lineage-17.1',
#    'head': '54b3645c197451de9808661d09be9b40b8b73e34',
#    'before': '3a74dc0d744c807ae64fc694f5dc9c6e0c5f3fee',
#    'commits': [{'sha': '54b3645c197451de9808661d09be9b40b8b73e34',
#      'author': {'email': 'jprimero155@gmail.com', 'name': 'Joshua Primero'},
#      'message': 'hlte: Correct define libinit variable\n\nSigned-off-by: Joshua Primero <jprimero155@gmail.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Jprimero15/android_device_samsung_hlte/commits/54b3645c197451de9808661d09be9b40b8b73e34'}]},
#   'public': True,
#   'created_at': '2020-02-08T14:56:00Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text
# Out:
# '{"all":[{"_id":"58e008ad0aac31001185ed0c","text":"The frequency of a domestic cat\'s purr is the same at which muscles and bones repair themselves.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":6,"userUpvoted":null},{"_id":"5b199196ce456e001424256a","text":"Cats can distinguish different flavors in water.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":6,"userUpvoted":null},{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"5b4912c60508220014ccfe99","text":"Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"5b4911940508220014ccfe94","text":"By the time a cat is 9 years old, it will only have been awake for three years of its life.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"59a60b8e6acf530020f3586e","text":"Cat owners are 17% more likely to have a graduate degree than non cat owners.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"599f89639a11040c4a163440","text":"Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"591d9b2f227c1a0020d26823","text":"Every year, nearly four million cats are eaten in China as a delicacy.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"59951d5ef2db18002031693c","text":"America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b01a447c6914f0014cc9a30","text":"The special sensory organ called the Jacobson\'s organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat\'s nasal cavity and is located on the roof of their mouth behind their teeth.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"58e008800aac31001185ed07","text":"Wikipedia has a recording of a cat meowing, because why not?","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"5b1b4055841d9700146158d3","text":"Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"58e007db0aac31001185ecf7","text":"There are cats who have survived falls from over 32 stories (320 meters) onto concrete.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"59a60ba66acf530020f35873","text":"Most cats don\'t like water because their coats do not insulate them well enough.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5a4d76916ef087002174c28b","text":"A cat’s no ...
